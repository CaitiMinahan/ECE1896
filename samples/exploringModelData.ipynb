# %%
import pandas as pd

# %%
df = pd.read_csv('../res/model_data/batemo_model_data.csv')

# %%
df
# Out:
#                V          I         SOC      T_surf  SOH
# 0       4.200000   0.000000  100.000000   25.000000  100
# 1       4.198758  -0.225199  100.000000   25.000000  100
# 2       4.197524  -0.449161  100.000000   25.000000  100
# 3       4.196296  -0.671867  100.000000   25.000000  100
# 4       4.190443  -1.733425  100.000000   25.000000  100
# ...          ...        ...         ...         ...  ...
# 732799  4.347699  40.000000   81.002048   98.977983   85
# 732800  4.348998  40.000000   81.230963   99.143580   85
# 732801  4.350224  40.000000   81.459877   99.309086   85
# 732802  4.353515  40.000000   82.110856   99.779493   85
# 732803  4.356468  40.000000   82.761835  100.249679   85
#
# [732804 rows x 5 columns]

# %%
import plotly.express as px

# plot multiple lines on a plotly line plot
# The data is large so we want to cut it down before we plot it
plot = df.iloc[::100, :]
fig = px.line(plot, x=plot.index, y=['V', 'I', 'SOC', 'T_surf', 'SOH'], title='Multiple Lines')
fig.show()
# Out:
# <div>                            <div id="4a3d552b-4c12-4ecd-a46f-97a94679fc1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a3d552b-4c12-4ecd-a46f-97a94679fc1b")) {                    Plotly.newPlot(                        "4a3d552b-4c12-4ecd-a46f-97a94679fc1b",                        [{"hovertemplate":"variable=V\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"V","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"V","showlegend":true,"x":[0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2600,2700,2800,2900,3000,3100,3200,3300,3400,3500,3600,3700,3800,3900,4000,4100,4200,4300,440
# ...
